# %%
s = "..."
sub = "GCGTATAGC"

# %%
for i in range(len(s)):
    if sub == s[i:i+len(sub)]:
        print(i+1, end=" ")
# Out:
# 4 31 65 82 89 96 115 148 171 214 229 251 305 364 380 433 440 499 561 568 650 657 755 770
